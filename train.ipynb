# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# Path to your 'side_project' folder
side_project_path = '/content/drive/MyDrive/side_project'

# List files in 'side_project'
file_list = os.listdir(side_project_path)
print(file_list)
# Out:
# ['chinhsuaanh.ipynb', 'gannhananh.ipynb', 'preparedata.ipynb', 'go_keo_A_sau_khi_chinh_sua', 'go_keo_B_va_C_sau_khi_chinh_sua', 'data']

# %%
from ultralytics import YOLO
from google.colab import drive

if __name__ == "__main__":
    drive.mount('/content/drive') # Mount Google Drive (if not already mounted)
    model = YOLO("yolov8n.pt")  # Load a pretrained YOLOv8n model
    data_yaml = '/content/drive/MyDrive/side_project/data/formatted_dataset/data.yaml'  # Replace with path to your data.yaml
    model.train(data=data_yaml, epochs=100, imgsz=640, batch=16, augment=True)  # Start training
    print("✅ Training hoàn tất!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 79.4MB/s]
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %%writefile /content/drive/MyDrive/side_project/data/formatted_dataset/data.yaml
#    train: train/images  # Path to your training images
#    val: val/images  # Path to your validation images
#    test: test/images # Path to your testing images
#
#    nc: 2  # Number of classes
#    names: ['go keo A','go keo B va C']  # Class names
# Out:
# Overwriting /content/drive/MyDrive/side_project/data/formatted_dataset/data.yaml

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.5/974.5 kB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...
